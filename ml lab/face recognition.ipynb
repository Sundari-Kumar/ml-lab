# %%
import os
import numpy as np
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# === Step 1: Load and preprocess the image dataset ===
dataset_path = r"C:\Users\MUTHU SELVI\Downloads\NEW\NEW\dataset"  # Replace with your dataset path

images = []
labels = []

for person_name in os.listdir(dataset_path):
    person_folder = os.path.join(dataset_path, person_name)
    if os.path.isdir(person_folder):
        for img_name in os.listdir(person_folder):
            img_path = os.path.join(person_folder, img_name)
            try:
                img = Image.open(img_path).convert("RGB")
                img = img.resize((64, 64))
                img = np.array(img) / 255.0  # Normalize
                images.append(img)
                labels.append(person_name)
            except Exception as e:
                print(f"Skipping {img_name}: {e}")

images = np.array(images)
labels = np.array(labels)

# === Step 2: Encode labels ===
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)
labels_encoded = to_categorical(labels_encoded)

# === Step 3: Train-test split ===
X_train, X_test, y_train, y_test = train_test_split(images, labels_encoded, test_size=0.2, random_state=42)

# === Step 4: Build the ANN model ===
model = Sequential([
    Flatten(input_shape=(64, 64, 3)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(labels_encoded.shape[1], activation='softmax')  # Output classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# === Step 5: Train the model ===
model.fit(X_train, y_train, epochs=30, validation_data=(X_test, y_test))

# === Step 6: Save model (optional) ===
model.save("face_ann_model.h5")

# === Step 7: Predict a test image ===
def recognize_person(image_path):
    try:
        img = Image.open(image_path).convert("RGB")
        img = img.resize((64, 64))
        img = np.array(img) / 255.0
        img = img.reshape(1, 64, 64, 3)

        prediction = model.predict(img)
        predicted_class = np.argmax(prediction)
        predicted_label = encoder.inverse_transform([predicted_class])[0]

        print(f"Predicted Person: {predicted_label}")
    except Exception as e:
        print(f"Error in recognition: {e}")

# === Example Usage ===
test_image = r"C:\Users\MUTHU SELVI\Pictures\Camera Roll\IMG20240307095759.jpg"  # Replace with a test image path
recognize_person(test_image)
# Out:
# Epoch 1/30
# C:\Users\MUTHU SELVI\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5714 - loss: 0.7081 - val_accuracy: 0.5000 - val_loss: 4.2352
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5714 - loss: 3.4023 - val_accuracy: 0.5000 - val_loss: 4.2547
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4286 - loss: 2.2054 - val_accuracy: 0.5000 - val_loss: 1.2545
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5714 - loss: 0.7637 - val_accuracy: 0.5000 - val_loss: 1.5812
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5714 - loss: 0.8316 - val_accuracy: 0.5000 - val_loss: 0.9830
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0427 - val_accuracy: 0.5000 - val_loss: 3.2087
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0489 - val_accuracy: 0.5000 - val_loss: 4.5977
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8571 - loss: 0.2996 - val_accuracy: 0.5000 - val_loss: 3.8435
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0452 - val_accuracy: 0.5000 - val_loss: 2.7803
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.5000 - val_loss: 1.8200
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.5000 - val_loss: 1.0931
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.5000 - val_loss: 0.6950
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.5757
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0370 - val_accuracy: 1.0000 - val_loss: 0.5599
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 0.5000 - val_loss: 0.6487
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.5000 - val_loss: 0.8955
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.5000 - val_loss: 1.2741
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.5000 - val_loss: 1.7064
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5000 - val_loss: 2.1421
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 8.4944e-04 - val_accuracy: 0.5000 - val_loss: 2.5598
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 4.5262e-04 - val_accuracy: 0.5000 - val_loss: 2.9515
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 2.5809e-04 - val_accuracy: 0.5000 - val_loss: 3.3152
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.6019e-04 - val_accuracy: 0.5000 - val_loss: 3.6504
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.1056e-04 - val_accuracy: 0.5000 - val_loss: 3.9443
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 8.6368e-05 - val_accuracy: 0.5000 - val_loss: 4.2103
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 7.6442e-05 - val_accuracy: 0.5000 - val_loss: 4.4543
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 7.5062e-05 - val_accuracy: 0.5000 - val_loss: 4.6776
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 7.9267e-05 - val_accuracy: 0.5000 - val_loss: 4.8815
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 8.7422e-05 - val_accuracy: 0.5000 - val_loss: 5.0674
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 9.8437e-05 - val_accuracy: 0.5000 - val_loss: 5.2363
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Predicted Person: Sundari
